# %% [markdown]
# <a href="https://colab.research.google.com/github/shivam9421/machine-learning/blob/main/finding_hostel_for_second_year.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
file_path1='/content/drive/MyDrive/Colab Notebooks/Final_hostel_Allotment.csv'
file_path2='/content/drive/MyDrive/Colab Notebooks/girls_hostell alloted.csv'

# %%
df1=pd.read_csv(file_path1)
df2=pd.read_csv(file_path2,header=None)

# %%
df2
# Out:
#        0        1                 2     3         4
# 0      1  2416091      ADHYA SAXENA  GH-1  4-Seater
# 1      2  2414141          CHETNA R  GH-1  4-Seater
# 2      3  2416071     BHUMI AGARWAL  GH-1  4-Seater
# 3      4  2413146    AMULYA GUNTURU  GH-1  4-Seater
# 4      5  2412111   KASHISH AGRAWAL  GH-1  4-Seater
# ..   ...      ...               ...   ...       ...
# 173  174  2416162       PROMA GHOSH  GH-4  3-Seater
# 174  175  2416057     DHARITRI DEKA  GH-4  3-Seater
# 175  176  2412102      SWARNIMA DAS  GH-4  3-Seater
# 176  177  2415100  SHAYMASRI BISWAS  GH-4  3-Seater
# 177  178  2416099    NENAVATH DIVYA  GH-4  3-Seater
#
# [178 rows x 5 columns]

# %%
df1.drop(columns=['Unnamed: 0','Unnamed: 5'],inplace=True)

# %%
df1.drop(0,inplace=True)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2357 entries, 1 to 2357
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 1  702 non-null    float64
#  1   Unnamed: 2  702 non-null    object
#  2   Unnamed: 3  702 non-null    object
#  3   Unnamed: 4  702 non-null    object
# dtypes: float64(1), object(3)
# memory usage: 73.8+ KB

# %%
df1
# Out:
#       Unnamed: 1       Unnamed: 2 Unnamed: 3 Unnamed: 4
# 1      2412064.0   SAYAN BHOWMICK       BH-8   3-seater
# 2      2412108.0  ARNAB SUTRADHAR       BH-8   3-seater
# 3      2412071.0      ANURAG KARN       BH-8   3-seater
# 4      2412046.0     TEJAS SHUKLA       BH-8   3-seater
# 5      2412083.0  DIPTAPRABHA DAS       BH-8   3-seater
# ...          ...              ...        ...        ...
# 2353         NaN              NaN        NaN        NaN
# 2354         NaN              NaN        NaN        NaN
# 2355         NaN              NaN        NaN        NaN
# 2356         NaN              NaN        NaN        NaN
# 2357         NaN              NaN        NaN        NaN
#
# [2357 rows x 4 columns]

# %%
df1.rename(columns={'Unnamed: 1':'scholar_id','Unnamed: 2':'Name','Unnamed: 3':'Hostel Alloted','Unnamed: 4':"Seater"},inplace=True)
df2.rename(columns={1:'scholar_id',2:'Name',3:'Hostel Alloted',4:"Seater"},inplace=True)

# %%
df2.drop(0,inplace=True)
df2
# Out:
#        0  scholar_id              Name Hostel Alloted    Seater
# 1      2     2414141          CHETNA R           GH-1  4-Seater
# 2      3     2416071     BHUMI AGARWAL           GH-1  4-Seater
# 3      4     2413146    AMULYA GUNTURU           GH-1  4-Seater
# 4      5     2412111   KASHISH AGRAWAL           GH-1  4-Seater
# 5      6     2416104         ANUSHRUTI           GH-1  4-Seater
# ..   ...         ...               ...            ...       ...
# 173  174     2416162       PROMA GHOSH           GH-4  3-Seater
# 174  175     2416057     DHARITRI DEKA           GH-4  3-Seater
# 175  176     2412102      SWARNIMA DAS           GH-4  3-Seater
# 176  177     2415100  SHAYMASRI BISWAS           GH-4  3-Seater
# 177  178     2416099    NENAVATH DIVYA           GH-4  3-Seater
#
# [177 rows x 5 columns]

# %%
df1.dropna(inplace=True)

# %%
df1
# Out:
#      scholar_id                   Name Hostel Alloted    Seater
# 1     2412064.0         SAYAN BHOWMICK           BH-8  3-seater
# 2     2412108.0        ARNAB SUTRADHAR           BH-8  3-seater
# 3     2412071.0            ANURAG KARN           BH-8  3-seater
# 4     2412046.0           TEJAS SHUKLA           BH-8  3-seater
# 5     2412083.0        DIPTAPRABHA DAS           BH-8  3-seater
# ..          ...                    ...            ...       ...
# 698  22103017.0     KENNY HAOMIN THANG           BH-4  1-seater
# 699  22105002.0  KHUPMUANSANG KHUPTONG           BH-4  1-seater
# 700  22105026.0     LUNKIM JAMTINTHANG           BH-4  1-seater
# 701  22107005.0         NGUR THANG JEL           BH-4  1-seater
# 702  22107001.0    SUANGOULIAN TONSING           BH-4  1-seater
#
# [702 rows x 4 columns]

# %%
df = pd.concat([df1, df2], ignore_index=True)
df.drop(columns=[0],inplace=True)

# %%
df
# Out:
#      scholar_id              Name Hostel Alloted    Seater
# 0     2412064.0    SAYAN BHOWMICK           BH-8  3-seater
# 1     2412108.0   ARNAB SUTRADHAR           BH-8  3-seater
# 2     2412071.0       ANURAG KARN           BH-8  3-seater
# 3     2412046.0      TEJAS SHUKLA           BH-8  3-seater
# 4     2412083.0   DIPTAPRABHA DAS           BH-8  3-seater
# ..          ...               ...            ...       ...
# 874   2416162.0       PROMA GHOSH           GH-4  3-Seater
# 875   2416057.0     DHARITRI DEKA           GH-4  3-Seater
# 876   2412102.0      SWARNIMA DAS           GH-4  3-Seater
# 877   2415100.0  SHAYMASRI BISWAS           GH-4  3-Seater
# 878   2416099.0    NENAVATH DIVYA           GH-4  3-Seater
#
# [879 rows x 4 columns]

# %%
def finding_hostelandseater_alloted(taking_input_scholar_id):

  hostel_alloted=df[df['scholar_id']==taking_input_scholar_id]
  return hostel_alloted

# %%
taking_input_scholar_id=float(input("Enter the scholar id: ")  )
finding_hostelandseater_alloted(taking_input_scholar_id)
